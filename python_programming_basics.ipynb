# %% [markdown]
# <a href="https://colab.research.google.com/github/hihi-villlage/html/blob/master/python_programming_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#単一行のコメント
# print('Comment practice!')
# コメントアウト
print('Comment practice!')　　# comment

# %%
print(1)
print (123)
# （）の中にある文字をリテラルという
# 数値リテラルと文字列リテラルがある
# 文字列リテラルは’’や””で囲む
print(1_000_000)
# Out:
# 1
# 123
# 1000000

# %%
# 数値の演算
print(1+1)
# +など計算記号は演算子
print(7//2) #割り算の商
print(7%2) #割り算の余り
print(2**3) #累乗
print(1+2*3)
#計算の順番は普通の計算と同じ。掛け算割り算優先。
#割り算の商や余りは足し引きより優先
# Out:
# 2
# 3
# 1
# 8
# 7

# %%
# エラー
# 全角が入っている場合 invalid charactor
# syntaxerror: 構文エラー

# %%
# エスケープシーケンス optionキー＋￥　「これは文字です」の意味になる
print ('I\'m fine.')
print('\"Hello\", World!')
print('Hello, \nWorld!')
print('\\')
# Out:
# I'm fine.
# "Hello", World!
# Hello,
# World!
# \

# %%
# 文字列の操作
print(len('1234567')) #文字の個数
# Out:
# 7

# %%
# 変数を使う
# 例題：　送料５００円込みの商品の値段を出力
delivery_fee=500　#＿で区切られている書き方をスネークケースという
print(1000+delivery_fee)
print(1200+delivery_fee)
print(1400+delivery_fee)
# print('-----------------')
print('送料が変わったら')
delivery_fee=300
print(1000+delivery_fee)
print(1200+delivery_fee)
print(1400+delivery_fee)
# Out:
# 1500
# 1700
# 1900
# 送料が変わったら
# 1300
# 1500
# 1700

# %%
# 予約語 すでにpythonで使われている言葉
import keyword
print(keyword.kwlist)
# 定数　変更されない数字とか. 普通大文字で書く。
PI = 3.14
TAX_RATE = 0.1
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# 複合代入演算子
age = 20
age += 2 # age = age + 2と同じ意味
print(age)
# Out:
# 22

# %%
# 変数のデータ型。代入するたびに型ががわる
i = 123
f = 3.14
s = '123'
b = True
print(type(i)) #整数型　数値型のこと
print(type(f)) #小数型　数値型のこと
print(type(s)) #文字列型
print(type(b)) #ブール型　真偽値のこと
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
